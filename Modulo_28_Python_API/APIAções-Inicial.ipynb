# %% [markdown]
# ### Alpha Vantage
#
# https://www.alphavantage.co/documentation/

# %% [markdown]
# #### Pegando cotações semanais - JSON

# %%
chave_api = 'TLEB9Z3TXHQ36UVK'

import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB3.SAO&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001DB143A0FD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~\anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB3.SAO&apikey=TLEB9Z3TXHQ36UVK (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DB143A0FD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 7
#       5 # replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
#       6 url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB3.SAO&apikey={chave_api}'
# ----> 7 r = requests.get(url)
#       8 data = r.json()
#      10 print(data)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB3.SAO&apikey=TLEB9Z3TXHQ36UVK (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DB143A0FD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %% [markdown]
# #### Pegando cotações semanais - CSV

# %%
import pandas as pd
from io import StringIO

url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=ITUB3.SAO&apikey={chave_api}&datatype=csv'
r = requests.get(url)
# data = r.json()

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#       timestamp    open    high     low   close  adjusted close   volume  \
# 0    2023-04-27   21.59   21.89   21.25   21.83         21.8300  2699500
# 1    2023-04-20   22.00   22.14   21.37   21.61         21.6100  2034300
# 2    2023-04-14   20.70   22.08   20.69   22.00         22.0000  2994900
# 3    2023-04-06   21.01   21.06   20.32   20.75         20.7500  2016900
# 4    2023-03-31   19.94   21.31   19.94   21.06         21.0600  2284800
# ..          ...     ...     ...     ...     ...             ...      ...
# 956  2005-02-10  350.00  350.00  350.00  350.00          2.2931        0
# 957  2005-02-02  330.00  340.00  330.00  340.00          2.2276        1
# 958  2005-01-28  345.00  345.00  334.00  334.00          2.1882        1
# 959  2005-01-21  344.00  345.00  340.00  340.00          2.2276        0
# 960  2005-01-12  350.00  350.00  344.00  344.00          2.2538       10
#
#      dividend amount
# 0             0.0000
# 1             0.0000
# 2             0.0000
# 3             0.0000
# 4             0.0176
# ..               ...
# 956           0.0000
# 957           0.0000
# 958           0.0000
# 959           0.0000
# 960           0.0000
#
# [961 rows x 8 columns]

# %% [markdown]
# ### Cotações

# %%
acoes = ['ITUB4', 'ABEV3', 'BBAS3']

compilada = pd.DataFrame()

for acao in acoes:
    url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={acao}.SAO&apikey={chave_api}&datatype=csv'
    r = requests.get(url)
    tabela = pd.read_csv(StringIO(r.text))
    lista_tabelas = [compilada, tabela]
    compilada = pd.concat(lista_tabelas)
    
display(compilada)
# Out:
#       symbol   open   high    low  price    volume   latestDay  previousClose  \
# 0  ITUB4.SAO  25.33  25.80  25.33  25.79  20872000  2023-04-27          25.34
# 0  ABEV3.SAO  14.18  14.25  14.01  14.16  16134300  2023-04-27          14.21
# 0  BBAS3.SAO  42.67  43.20  42.52  42.72   6152200  2023-04-27          42.67
#
#    change changePercent
# 0    0.45       1.7758%
# 0   -0.05      -0.3519%
# 0    0.05       0.1172%

# %% [markdown]
# ### Encontrar ativos

# %%
url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=amazon&apikey={chave_api}&datatype=csv'
r = requests.get(url)
# data = r.json()

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#        symbol                      name    type            region marketOpen  \
# 0        AMZN            Amazon.com Inc  Equity     United States      09:30
# 1     AMZ.DEX            Amazon.com Inc  Equity             XETRA      08:00
# 2     AMZ.FRK            Amazon.com Inc  Equity         Frankfurt      08:00
# 3  AMZO34.SAO            Amazon.com Inc  Equity  Brazil/Sao Paolo      10:00
# 4    0R1O.LON           Amazon.com Inc.  Equity    United Kingdom      08:00
# 5    AMZ1.FRK  AMAZON.COM INC.CDR DL-01  Equity         Frankfurt      08:00
# 6        AZFL    Amazonas Florestal Ltd  Equity     United States      09:30
#
#   marketClose timezone currency  matchScore
# 0       16:00   UTC-04      USD      0.8000
# 1       20:00   UTC+02      EUR      0.6000
# 2       20:00   UTC+02      EUR      0.6000
# 3       17:30   UTC-03      BRL      0.6000
# 4       16:30   UTC+01      USD      0.5714
# 5       20:00   UTC+02      EUR      0.5000
# 6       16:00   UTC-04      USD      0.4286

# %% [markdown]
# ### Informações de Resultado

# %%
url = f'https://www.alphavantage.co/query?function=EARNINGS&symbol=AMZN&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'symbol': 'AMZN', 'annualEarnings': [{'fiscalDateEnding': '2023-03-31', 'reportedEPS': '0'}, {'fiscalDateEnding': '2022-12-31', 'reportedEPS': '0.97'}, {'fiscalDateEnding': '2021-12-31', 'reportedEPS': '2.15'}, {'fiscalDateEnding': '2020-12-31', 'reportedEPS': '2.09'}, {'fiscalDateEnding': '2019-12-31', 'reportedEPS': '1.14'}, {'fiscalDateEnding': '2018-12-31', 'reportedEPS': '1'}, {'fiscalDateEnding': '2017-12-31', 'reportedEPS': '0.23'}, {'fiscalDateEnding': '2016-12-31', 'reportedEPS': '0.25'}, {'fiscalDateEnding': '2015-12-31', 'reportedEPS': '0.06'}, {'fiscalDateEnding': '2014-12-31', 'reportedEPS': '-0.03'}, {'fiscalDateEnding': '2013-12-31', 'reportedEPS': '-0.07'}, {'fiscalDateEnding': '2012-12-31', 'reportedEPS': '0.02'}, {'fiscalDateEnding': '2011-12-31', 'reportedEPS': '0.07'}, {'fiscalDateEnding': '2010-12-31', 'reportedEPS': '0.13'}, {'fiscalDateEnding': '2009-12-31', 'reportedEPS': '0.1'}, {'fiscalDateEnding': '2008-12-31', 'reportedEPS': '0.08'}, {'fiscalDateEnding': '2007-12-31', 'reportedEPS': '0.05'}, {'fiscalDateEnding': '2006-12-31', 'reportedEPS': '0.12'}, {'fiscalDateEnding': '2005-12-31', 'reportedEPS': '0.11'}, {'fiscalDateEnding': '2004-12-31', 'reportedEPS': '0.05'}, {'fiscalDateEnding': '2003-12-31', 'reportedEPS': '0.04'}, {'fiscalDateEnding': '2002-12-31', 'reportedEPS': '-0.1024'}, {'fiscalDateEnding': '2001-12-31', 'reportedEPS': '0.06'}, {'fiscalDateEnding': '2000-12-31', 'reportedEPS': '-0.06'}, {'fiscalDateEnding': '1999-12-31', 'reportedEPS': '-0.06'}, {'fiscalDateEnding': '1998-12-31', 'reportedEPS': '-0.25'}, {'fiscalDateEnding': '1997-12-31', 'reportedEPS': '-0.08'}], 'quarterlyEarnings': [{'fiscalDateEnding': '2023-03-31', 'reportedDate': '2023-04-27', 'reportedEPS': 'None', 'estimatedEPS': '0.21', 'surprise': 'None', 'surprisePercentage': 'None'}, {'fiscalDateEnding': '2022-12-31', 'reportedDate': '2023-02-02', 'reportedEPS': '0.25', 'estimatedEPS': '0.18', 'surprise': '0.07', 'surprisePercentage': '38.8889'}, {'fiscalDateEnding': '2022-09-30', 'reportedDate': '2022-10-27', 'reportedEPS': '0.17', 'estimatedEPS': '0.22', 'surprise': '-0.05', 'surprisePercentage': '-22.7273'}, {'fiscalDateEnding': '2022-06-30', 'reportedDate': '2022-07-28', 'reportedEPS': '0.18', 'estimatedEPS': '0.14', 'surprise': '0.04', 'surprisePercentage': '28.5714'}, {'fiscalDateEnding': '2022-03-31', 'reportedDate': '2022-04-28', 'reportedEPS': '0.37', 'estimatedEPS': '0.42', 'surprise': '-0.05', 'surprisePercentage': '-11.9048'}, {'fiscalDateEnding': '2021-12-31', 'reportedDate': '2022-02-03', 'reportedEPS': '0.29', 'estimatedEPS': '0.18', 'surprise': '0.11', 'surprisePercentage': '61.1111'}, {'fiscalDateEnding': '2021-09-30', 'reportedDate': '2021-10-28', 'reportedEPS': '0.31', 'estimatedEPS': '0.45', 'surprise': '-0.14', 'surprisePercentage': '-31.1111'}, {'fiscalDateEnding': '2021-06-30', 'reportedDate': '2021-07-29', 'reportedEPS': '0.76', 'estimatedEPS': '0.62', 'surprise': '0.14', 'surprisePercentage': '22.5806'}, {'fiscalDateEnding': '2021-03-31', 'reportedDate': '2021-04-29', 'reportedEPS': '0.79', 'estimatedEPS': '0.48', 'surprise': '0.31', 'surprisePercentage': '64.5833'}, {'fiscalDateEnding': '2020-12-31', 'reportedDate': '2021-02-02', 'reportedEPS': '0.7', 'estimatedEPS': '0.36', 'surprise': '0.34', 'surprisePercentage': '94.4444'}, {'fiscalDateEnding': '2020-09-30', 'reportedDate': '2020-10-29', 'reportedEPS': '0.62', 'estimatedEPS': '0.37', 'surprise': '0.25', 'surprisePercentage': '67.5676'}, {'fiscalDateEnding': '2020-06-30', 'reportedDate': '2020-07-30', 'reportedEPS': '0.52', 'estimatedEPS': '0.07', 'surprise': '0.45', 'surprisePercentage': '642.8571'}, {'fiscalDateEnding': '2020-03-31', 'reportedDate': '2020-04-30', 'reportedEPS': '0.25', 'estimatedEPS': '0.31', 'surprise': '-0.06', 'surprisePercentage': '-19.3548'}, {'fiscalDateEnding': '2019-12-31', 'reportedDate': '2020-01-30', 'reportedEPS': '0.32', 'estimatedEPS': '0.2', 'surprise': '0.12', 'surprisePercentage': '60'}, {'fiscalDateEnding':  ...

# %%
import pprint

# pprint.pprint(data)

resultado = pd.DataFrame(data['annualEarnings'])
display(resultado)
# Out:
#    fiscalDateEnding reportedEPS
# 0        2023-03-31           0
# 1        2022-12-31        0.97
# 2        2021-12-31        2.15
# 3        2020-12-31        2.09
# 4        2019-12-31        1.14
# 5        2018-12-31           1
# 6        2017-12-31        0.23
# 7        2016-12-31        0.25
# 8        2015-12-31        0.06
# 9        2014-12-31       -0.03
# 10       2013-12-31       -0.07
# 11       2012-12-31        0.02
# 12       2011-12-31        0.07
# 13       2010-12-31        0.13
# 14       2009-12-31         0.1
# 15       2008-12-31        0.08
# 16       2007-12-31        0.05
# 17       2006-12-31        0.12
# 18       2005-12-31        0.11
# 19       2004-12-31        0.05
# 20       2003-12-31        0.04
# 21       2002-12-31     -0.1024
# 22       2001-12-31        0.06
# 23       2000-12-31       -0.06
# 24       1999-12-31       -0.06
# 25       1998-12-31       -0.25
# 26       1997-12-31       -0.08
